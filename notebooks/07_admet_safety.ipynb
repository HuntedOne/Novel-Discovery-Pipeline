# %% [markdown]
# # Are these molecules selective, safe, and drug-like enough to be worth a look?
#
# > **Pipeline stage:** Stage 5 / 6
# > **Question this answers:** Are these molecules selective, safe, and drug-like enough to be worth a look?
# > **Maturity:** Mature
# > **Key caveat:** ADMET predicts LIABILITIES and PROPERTIES, not the therapeutic or subjective EFFECT. Clean ADMET means 'developable', not 'good'.
#
# *This is a learning notebook. Read the markdown between cells — the goal is to understand what the tool does and how it hands off to the next stage, not to discover anything.*

# %% [markdown]
# Read **docs/background/07_admet_and_safety.md**.
#
# We screen the known ligands (and any molecules from notebook 06) with **ADMET-AI** and **RDKit** filters, then assemble a **candidate scorecard**: the closest this sandbox comes to 'worth a closer look'.

# %%
# TODO (Claude Code): run ADMET-AI on the molecule set; collect hERG, BBB, and other endpoints.
# Add RDKit rule-of-thumb flags (Lipinski, TPSA, logP) for drug-likeness / BBB plausibility.
# Highlight 5-HT2B-type and hERG liabilities prominently.
pass

# %%
# TODO (Claude Code): build a scorecard DataFrame combining:
#   affinity signal (from 04/05) + selectivity flags (5-HT2B/hERG) + BBB + drug-likeness.
# Sort to a shortlist. Make explicit in markdown what the scorecard does NOT claim.
pass

# %% [markdown]
# ---
# ## What you should now understand
# How ADMET prediction screens for the safety liabilities that matter for serotonergic agonists (5-HT2B, hERG, BBB), how to assemble a multi-property candidate scorecard, and the firm ceiling that 'developable' is not 'effective' or 'safe in humans'.
#
# ## Hands off to
# **`08_mini_pipeline.ipynb`** — chain the stages into one flow and see the handoffs.
