# %% [markdown]
# # Where on the receptor do molecules bind?
#
# > **Pipeline stage:** Stage 2 / 5
# > **Question this answers:** Where on the receptor do molecules bind?
# > **Maturity:** Mature (orthosteric); Frontier (cryptic)
# > **Key caveat:** Geometry-based and ML-based pocket finders disagree sometimes — use consensus. Cryptic/allosteric sites only appear when the protein moves.
#
# *This is a learning notebook. Read the markdown between cells — the goal is to understand what the tool does and how it hands off to the next stage, not to discover anything.*

# %% [markdown]
# Read **docs/background/05_docking_explained.md** (pocket section).
#
# We'll find the binding pocket with **P2Rank** (ML) and **fpocket** (geometry), then look at where they agree. Knowing the pocket is the prerequisite for docking.

# %%
# TODO (Claude Code): run P2Rank on the structure from notebook 02.
# P2Rank is a standalone Java tool — wrap the CLI call, parse the predicted pocket residues.
# Provide a ../data/ fallback of precomputed pocket residues so this runs without P2Rank installed.
pass

# %%
# TODO (Claude Code): run fpocket and compare pockets to P2Rank (consensus residues).
# Visualize the top pocket on the structure with py3Dmol (highlight pocket residues).
pass

# %% [markdown]
# ### Why allosteric/cryptic sites matter
# Markdown for Claude Code: explain that a site *away* from the serotonin pocket could let a designer tune the receptor without competing with serotonin — and that finding such sites was a headline IsoDDE capability.

# %% [markdown]
# ---
# ## What you should now understand
# How binding-site prediction works, why two methods are better than one, and what cryptic/allosteric sites are and why they're interesting for novel design.
#
# ## Hands off to
# **`04_docking_classical.ipynb`** — dock known ligands into this pocket.
