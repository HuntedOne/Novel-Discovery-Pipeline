# %% [markdown]
# # What does the 5-HT2A receptor look like, and in which state?
#
# > **Pipeline stage:** Stage 1
# > **Question this answers:** What does the 5-HT2A receptor look like, and in which state?
# > **Maturity:** Mature
# > **Key caveat:** A receptor is a shape-shifter (active vs inactive). Which state you model changes everything downstream.
#
# *This is a learning notebook. Read the markdown between cells — the goal is to understand what the tool does and how it hands off to the next stage, not to discover anything.*

# %% [markdown]
# Read **docs/background/04_structure_prediction_and_cofolding.md**.
#
# **Light path:** download a public experimental 5-HT2A structure from the PDB and visualize it. **Full path (optional):** predict it with OpenFold-3 / Boltz-2 and compare. We start light so this runs anywhere.

# %%
# TODO (Claude Code): fetch a public 5-HT2A PDB entry into ../data/ and load it.
# Search the PDB for a 5-HT2A (HTR2A) structure; store the chosen PDB ID here with a comment.
import os
PDB_ID = None  # e.g. '6A93' — set after verifying it is a real 5-HT2A structure
assert PDB_ID, 'Set PDB_ID to a verified 5-HT2A structure before running.'

# %%
# Visualize with py3Dmol. Label the binding region.
import py3Dmol
# TODO (Claude Code): load the PDB file from ../data/ and render cartoon + ligand sticks.
view = py3Dmol.view(width=700, height=450)
# view.addModel(open(path).read(), 'pdb'); view.setStyle({'cartoon': {'color':'spectrum'}})
# view.zoomTo(); view.show()

# %% [markdown]
# ### Active vs inactive states
# Discuss (markdown for Claude Code to expand): how an agonist-bound active state differs from the inactive state, and why predicting the *right* state matters for docking and for the signaling-bias question (Primer 2).

# %% [markdown]
# ---
# ## What you should now understand
# Where to get a target structure, how to view it in 3D, and why receptor conformational state is a first-class concern — not a detail.
#
# ## Hands off to
# **`03_pockets.ipynb`** — locate the pocket where ligands actually bind.
