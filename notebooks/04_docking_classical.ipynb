# %% [markdown]
# # Do the known ligands dock into the pocket, and how are they ranked?
#
# > **Pipeline stage:** Stage 2
# > **Question this answers:** Do the known ligands dock into the pocket, and how are they ranked?
# > **Maturity:** Mostly mature
# > **Key caveat:** A docking SCORE is not a binding affinity, and neither is an effect. Scores rank/triage; they do not confirm.
#
# *This is a learning notebook. Read the markdown between cells — the goal is to understand what the tool does and how it hands off to the next stage, not to discover anything.*

# %% [markdown]
# Read **docs/background/05_docking_explained.md**.
#
# We dock the four molecules from notebook 01 into the pocket from notebook 03 using **AutoDock Vina** (open, CPU-friendly). The teaching point: see how scores rank the known ligands only *roughly*, and that ranking says nothing about agonism.

# %%
# TODO (Claude Code): prepare receptor + ligands (RDKit/Meeko) and run AutoDock Vina.
# Steps: generate 3D ligand conformers, assign charges, define the search box from the
# pocket residues (notebook 03), run Vina, collect best score per ligand.
# Provide a ../data/ precomputed score table as fallback.
pass

# %%
# TODO (Claude Code): tabulate scores and DISCUSS the ranking vs known pharmacology.
# Make the caveat loud in markdown: score != affinity != efficacy.
pass

# %%
# Optional: if Gnina is available, re-score and compare to Vina to show method variance.
pass

# %% [markdown]
# ---
# ## What you should now understand
# How classical docking produces poses and scores, how to set up a docking run, and — most importantly — how little a score alone tells you. You ranked real ligands and saw the noise.
#
# ## Hands off to
# **`05_cofolding_affinity.ipynb`** — the deep-learning version that also estimates affinity.
