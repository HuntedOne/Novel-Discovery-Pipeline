# %% [markdown]
# # How do the stages connect into one flow — and where does confidence drop?
#
# > **Pipeline stage:** Capstone
# > **Question this answers:** How do the stages connect into one flow — and where does confidence drop?
# > **Maturity:** Composite
# > **Key caveat:** This chains tools to show HANDOFFS, not to discover. Confidence falls as you move up the stages; the notebook makes that visible.
#
# *This is a learning notebook. Read the markdown between cells — the goal is to understand what the tool does and how it hands off to the next stage, not to discover anything.*

# %% [markdown]
# This capstone chains a single example end-to-end:
#
# `known ligand → pocket (03) → dock (04) → ADMET scorecard (07)`
#
# The aim is to *feel* the pipeline as one motion and to watch the confidence gradient (Primer 2) in action — solid at structure/binding, thinning toward the top.

# %%
# TODO (Claude Code): import/reuse helpers from src/ and run the chain on one ligand.
# At each handoff, print a short 'CONFIDENCE: high/medium/low — why' banner.
pass

# %%
# TODO (Claude Code): produce one summary figure/table of the whole run,
# ending with an explicit 'what we still cannot say' cell (efficacy, bias, experience).
pass

# %% [markdown]
# ---
# ## What you should now understand
# How the open-source tools compose into a single pipeline, where each handoff happens, and — the durable lesson — exactly where computational confidence runs out and the human-clinical work begins.
#
# ## Hands off to
# Back to **docs/background/09_reading_new_developments.md** — now use the pipeline as a lens to evaluate the next new model you read about.
