# %% [markdown]
# # Can a model invent new candidate molecules toward a goal?
#
# > **Pipeline stage:** Stage 3 / 4 (design)
# > **Question this answers:** Can a model invent new candidate molecules toward a goal?
# > **Maturity:** Active research
# > **Key caveat:** It generates STRUCTURES, not experiences. Reward hacking is real — inspect output. Training bias constrains exploration.
#
# *This is a learning notebook. Read the markdown between cells — the goal is to understand what the tool does and how it hands off to the next stage, not to discover anything.*

# %% [markdown]
# Read **docs/background/06_generative_design.md**.
#
# We run a *tiny* **REINVENT 4** generate→score→optimize loop with a deliberately simple scoring function, so you can **watch molecules drift toward an objective**. The point is the *mechanism*, not discovery.

# %%
# TODO (Claude Code): configure a minimal REINVENT 4 run (TOML), small epoch count.
# Scoring function: start simple (e.g. similarity to a tryptamine scaffold + QED drug-likeness).
# Later, show how a docking score or ADMET score could be plugged in as the reward.
# Provide a ../data/ precomputed run-log fallback so the loop is inspectable without a GPU.
pass

# %%
# TODO (Claude Code): plot score distribution per epoch to SHOW the drift.
# Draw a few generated molecules from early vs late epochs with RDKit.
pass

# %% [markdown]
# ### Caveats made visible
# Markdown for Claude Code: point out any reward-hacked / unrealistic molecules, discuss SMILES validity rate, and reconnect to Primer 2 — a high reward is a *hypothesis*, and nothing here predicts agonism, bias, or experience.

# %% [markdown]
# ---
# ## What you should now understand
# How the generate→score→optimize loop works, how the scoring function IS the design objective, why generated molecules are hypotheses not answers, and how generation would feed the safety screen next.
#
# ## Hands off to
# **`07_admet_safety.ipynb`** — filter molecules for safety and drug-likeness.
